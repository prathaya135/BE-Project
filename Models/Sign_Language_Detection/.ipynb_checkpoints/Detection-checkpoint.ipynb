# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D,MaxPooling,Flatten2D,Flatten,Dropout
from tensorflow.keras.models import Sequential
